# %% [markdown]
# Home prices, weather, stock price - Predicted values are CONTINUOUS. --- LINEAR REGRESSION
# Emails(spam or not), will customer buy life insurance, which party will a person vote for? - Predicted values are CATEGORICAL. - CLASSIFICATION
#
# LOGISTIC REGRESSION: to solve these classification issues.

# %% [markdown]
# ![Sigmoid](attachment:ce98d610-964a-425c-91f7-35fc632fb928.png)
# The two pics for sigmoid
# Applying sigmoid equation on top of linear equation

# %%
!(logistic_regression.png)
# Out:
# 'logistic_regression.png' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
df = pd.read_csv('../Files/Logistic_Regression_Binary/insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
import matplotlib.pyplot as plt
plt.scatter(df.age,df.bought_insurance,marker='+',color='green')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(df[['age']],df['bought_insurance'],train_size=0.9)

# %%
X_test
# Out:
#     age
# 13   29
# 24   50
# 10   18

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
# first column is probability of the row fella not buying, second column is probability of the row fella buying
model.predict_proba(X_test)
# Out:
# array([[0.76677091, 0.23322909],
#        [0.19262279, 0.80737721],
#        [0.92852414, 0.07147586]])
